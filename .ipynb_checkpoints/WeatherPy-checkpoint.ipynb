# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint
from scipy import stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 621

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

temp = []
humid = []
cloud = []
wind = []
cities2 = []
lat = []
lon = []

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

for city in cities:
    print (f'Index: {cities.index(city)}')
    print (f'Trying to get data for {city} \n')
    try:
        response = requests.get(query_url + city).json()
        cities2.append(response['name'])
        temp.append(response['main']['temp'])
        humid.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
    except:
           print(f'{city} pull failed \n')
# Out:
# Index: 0
# Trying to get data for okato
#
# Index: 1
# Trying to get data for rikitea
#
# Index: 2
# Trying to get data for auki
#
# Index: 3
# Trying to get data for hasaki
#
# Index: 4
# Trying to get data for ushuaia
#
# Index: 5
# Trying to get data for noumea
#
# Index: 6
# Trying to get data for nome
#
# Index: 7
# Trying to get data for busselton
#
# Index: 8
# Trying to get data for kavaratti
#
# Index: 9
# Trying to get data for ayan
#
# Index: 10
# Trying to get data for cape town
#
# Index: 11
# Trying to get data for belushya guba
#
# belushya guba pull failed
#
# Index: 12
# Trying to get data for chuy
#
# Index: 13
# Trying to get data for esperance
#
# Index: 14
# Trying to get data for mataura
#
# Index: 15
# Trying to get data for vila velha
#
# Index: 16
# Trying to get data for dauriya
#
# Index: 17
# Trying to get data for astrea
#
# Index: 18
# Trying to get data for lucapa
#
# Index: 19
# Trying to get data for port blair
#
# Index: 20
# Trying to get data for taoudenni
#
# Index: 21
# Trying to get data for huron
#
# Index: 22
# Trying to get data for bredasdorp
#
# Index: 23
# Trying to get data for mackenzie
#
# Index: 24
# Trying to get data for vaini
#
# Index: 25
# Trying to get data for bossembele
#
# bossembele pull failed
#
# Index: 26
# Trying to get data for lagoa
#
# Index: 27
# Trying to get data for hamilton
#
# Index: 28
# Trying to get data for geraldton
#
# Index: 29
# Trying to get data for grand centre
#
# grand centre pull failed
#
# Index: 30
# Trying to get data for mys shmidta
#
# mys shmidta pull failed
#
# Index: 31
# Trying to get data for hilo
#
# Index: 32
# Trying to get data for tepla
#
# Index: 33
# Trying to get data for hami
#
# Index: 34
# Trying to get data for punta arenas
#
# Index: 35
# Trying to get data for varna
#
# Index: 36
# Trying to get data for barentsburg
#
# barentsburg pull failed
#
# Index: 37
# Trying to get data for khakurinokhabl
#
# Index: 38
# Trying to get data for pembroke
#
# Index: 39
# Trying to get data for shimoda
#
# Index: 40
# Trying to get data for jamestown
#
# Index: 41
# Trying to get data for taolanaro
#
# taolanaro pull failed
#
# Index: 42
# Trying to get data for pevek
#
# Index: 43
# Trying to get data for khatanga
#
# Index: 44
# Trying to get data for tomaszow lubelski
#
# Index: 45
# Trying to get data for ilebo
#
# Index: 46
# Trying to get data for hermanus
#
# Index: 47
# Trying to get data for thompson
#
# Index: 48
# Trying to get data for albany
#
# Index: 49
# Trying to get data for kamskoye ustye
#
# Index: 50
# Trying to get data for lata
#
# Index: 51
# Trying to get data for aklavik
#
# Index: 52
# Trying to get data for ormara
#
# Index: 53
# Trying to get data for georgetown
#
# Index: 54
# Trying to get data for monrovia
#
# Index: 55
# Trying to get data for east london
#
# Index: 56
# Trying to get data for praia
#
# Index: 57
# Trying to get data for kasganj
#
# Index: 58
# Trying to get data for xining
#
# Index: 59
# Trying to get data for cidreira
#
# Index: 60
# Trying to get data for dunedin
#
# Index: 61
# Trying to get data for lovington
#
# Index: 62
# Trying to get data for pochutla
#
# Index: 63
# Trying to get data for zhigalovo
#
# Index: 64
# Trying to get data for teknaf
#
# Index: 65
# Trying to get data for rio brilhante
#
# Index: 66
# Trying to get data for aden
#
# Index: 67
# Trying to get data for barcelos
#
# Index: 68
# Trying to get data for mineral wells
#
# Index: 69
# Trying to get data for qaqortoq
#
# Index: 70
# Trying to get data for sao filipe
#
# Index: 71
# Trying to get data for flinders
#
# Index: 72
# Trying to get data for tyulgan
#
# Index: 73
# Trying to get data for tonj
#
# Index: 74
# Trying to get data for fort nelson
#
# Index: 75
# Trying to get data for sisimiut
#
# Index: 76
# Trying to get data for illoqqortoormiut
#
# illoqqortoormiut pull failed
#
# Index: 77
# Trying to get data for lasa
#
# Index: 78
# Trying to get data for pafos
#
# Index: 79
# Trying to get data for port alfred
#
# Index: 80
# Trying to get data for bethel
#
# Index: 81
# Trying to get data for saint anthony
#
# Index: 82
# Trying to get data for tual
#
# Index: 83
# Trying to get data for viedma
#
# Index: 84
# Trying to get data for krasnokamensk
#
# Index: 85
# Trying to get data for saskylakh
#
# Index: 86
# Trying to get data for sioux lookout
#
# Index: 87
# Trying to get data for dubrovka
#
# Index: 88
# Trying to get data for babenhausen
#
# Index: 89
# Trying to get data for carnarvon
#
# Index: 90
# Trying to get data for arraial do cabo
#
# Index: 91
# Trying to get data for bluff
#
# Index: 92
# Trying to get data for ahumada
#
# ahumada pull failed
#
# Index: 93
# Trying to get data for hobart
#
# Index: 94
# Trying to get data for vaitupu
#
# vaitupu pull failed
#
# Index: 95
# Trying to get data for sitka
#
# Index: 96
# Trying to get data for fortuna
#
# Index: 97
# Trying to get data for barrow
#
# Index: 98
# Trying to get data for llandrindod wells
#
# Index: 99
# Trying to get data for mishelevka
#
# Index: 100
# Trying to get data for ostrovnoy
#
# Index: 101
# Trying to get data for provideniya
#
# Index: 102
# Trying to get data for ponta do sol
#
# Index: 103
# Trying to get data for talnakh
#
# Index: 104
# Trying to get data for nikolskoye
#
# Index: 105
# Trying to get data for yanam
#
# Index: 106
# Trying to get data for lompoc
#
# Index: 107
# Trying to get data for saint george
#
# Index: 108
# Trying to get data for haibowan
#
# haibowan pull failed
#
# Index: 109
# Trying to get data for kutum
#
# Index: 110
# Trying to get data for upernavik
#
# Index: 111
# Trying to get data for kalispell
#
# Index: 112
# Trying to get data for vila franca do campo
#
# Index: 113
# Trying to get data for armidale
#
# Index: 114
# Trying to get data for khani
#
# Index: 115
# Trying to get data for walvis bay
#
# Index: 116
# Trying to get data for kapaa
#
# Index: 117
# Trying to get data for jambi
#
# Index: 118
# Trying to get data for katsuura
#
# Index: 119
# Trying to get data for tiksi
#
# Index: 120
# Trying to get data for denpasar
#
# Index: 121
# Trying to get data for kruisfontein
#
# Index: 122
# Trying to get data for mar del plata
#
# Index: 123
# Trying to get data for puerto ayora
#
# Index: 124
# Trying to get data for new norfolk
#
# Index: 125
# Trying to get data for wanaka
#
# Index: 126
# Trying to get data for assiniboia
#
# Index: 127
# Trying to get data for mentok
#
# mentok pull failed
#
# Index: 128
# Trying to get data for krasnogorsk
#
# Index: 129
# Trying to get data for iranshahr
#
# Index: 130
# Trying to get data for ribeira grande
#
# Index: 131
# Trying to get data for leningradskiy
#
# Index: 132
# Trying to get data for fairlie
#
# Index: 133
# Trying to get data for ambon
#
# Index: 134
# Trying to get data for rawson
#
# Index: 135
# Trying to get data for saleaula
#
# saleaula pull failed
#
# Index: 136
# Trying to get data for gimli
#
# Index: 137
# Trying to get data for saldanha
#
# Index: 138
# Trying to get data for thornbury
#
# Index: 139
# Trying to get data for mushie
#
# Index: 140
# Trying to get data for eldorado
#
# Index: 141
# Trying to get data for butaritari
#
# Index: 142
# Trying to get data for varzea da palma
#
# Index: 143
# Trying to get data for brae
#
# Index: 144
# Trying to get data for te anau
#
# Index: 145
# Trying to get data for sorland
#
# Index: 146
# Trying to get data for murgab
#
# Index: 147
# Trying to get data for san carlos
#
# Index: 148
# Trying to get data for miguel pereira
#
# Index: 149
# Trying to get data for jumla
#
# Index: 150
# Trying to get data for derzhavinsk
#
# Index: 151
# Trying to get data for japura
#
# Index: 152
# Trying to get data for znamenskoye
#
# Index: 153
# Trying to get data for bairiki
#
# Index: 154
# Trying to get data for paamiut
#
# Index: 155
# Trying to get data for mokhsogollokh
#
# Index: 156
# Trying to get data for girne
#
# Index: 157
# Trying to get data for presidente medici
#
# Index: 158
# Trying to get data for samarkand
#
# Index: 159
# Trying to get data for komsomolskiy
#
# Index: 160
# Trying to get data for batagay-alyta
#
# Index: 161
# Trying to get data for wanning
#
# Index: 162
# Trying to get data for cabo san lucas
#
# Index: 163
# Trying to get data for yellowknife
#
# Index: 164
# Trying to get data for mount isa
#
# Index: 165
# Trying to get data for acapulco
#
# Index: 166
# Trying to get data for san quintin
#
# Index: 167
# Trying to get data for samusu
#
# samusu pull failed
#
# Index: 168
# Trying to get data for mahebourg
#
# Index: 169
# Trying to get data for salalah
#
# Index: 170
# Trying to get data for kandrian
#
# Index: 171
# Trying to get data for verkhnevilyuysk
#
# Index: 172
# Trying to get data for victoria
#
# Index: 173
# Trying to get data for cherskiy
#
# Index: 174
# Trying to get data for luba
#
# Index: 175
# Trying to get data for westport
# Index: 176
# Trying to get data for toliary
#
# toliary pull failed
#
# Index: 177
# Trying to get data for highland springs
#
# Index: 178
# Trying to get data for umm lajj
#
# Index: 179
# Trying to get data for krasnoselkup
#
# Index: 180
# Trying to get data for srednekolymsk
#
# Index: 181
# Trying to get data for bondo
#
# Index: 182
# Trying to get data for tarutyne
#
# Index: 183
# Trying to get data for sinnamary
#
# Index: 184
# Trying to get data for hirara
#
# Index: 185
# Trying to get data for castro
#
# Index: 186
# Trying to get data for pontianak
#
# Index: 187
# Trying to get data for lodwar
#
# Index: 188
# Trying to get data for thunder bay
#
# Index: 189
# Trying to get data for yumen
#
# Index: 190
# Trying to get data for nanortalik
#
# Index: 191
# Trying to get data for karratha
#
# Index: 192
# Trying to get data for sokolo
#
# Index: 193
# Trying to get data for atuona
#
# Index: 194
# Trying to get data for saint-philippe
#
# Index: 195
# Trying to get data for houma
#
# Index: 196
# Trying to get data for mecca
#
# Index: 197
# Trying to get data for nizhneyansk
#
# nizhneyansk pull failed
#
# Index: 198
# Trying to get data for zhanatas
#
# zhanatas pull failed
#
# Index: 199
# Trying to get data for bengkulu
#
# Index: 200
# Trying to get data for hithadhoo
#
# Index: 201
# Trying to get data for sentyabrskiy
#
# sentyabrskiy pull failed
#
# Index: 202
# Trying to get data for kaitangata
#
# Index: 203
# Trying to get data for makasar
#
# Index: 204
# Trying to get data for inirida
#
# Index: 205
# Trying to get data for rio rancho
#
# Index: 206
# Trying to get data for meyungs
#
# meyungs pull failed
#
# Index: 207
# Trying to get data for richards bay
#
# Index: 208
# Trying to get data for honningsvag
#
# Index: 209
# Trying to get data for aloleng
#
# Index: 210
# Trying to get data for skalistyy
#
# skalistyy pull failed
#
# Index: 211
# Trying to get data for chenzhou
#
# Index: 212
# Trying to get data for villazon
#
# Index: 213
# Trying to get data for severo-kurilsk
#
# Index: 214
# Trying to get data for galiwinku
#
# galiwinku pull failed
#
# Index: 215
# Trying to get data for qaanaaq
#
# Index: 216
# Trying to get data for torbay
#
# Index: 217
# Trying to get data for malakal
#
# Index: 218
# Trying to get data for broome
#
# Index: 219
# Trying to get data for souillac
#
# Index: 220
# Trying to get data for kamenka
#
# Index: 221
# Trying to get data for yerbogachen
#
# Index: 222
# Trying to get data for kidal
#
# Index: 223
# Trying to get data for labuan
#
# Index: 224
# Trying to get data for capao da canoa
#
# Index: 225
# Trying to get data for sur
#
# Index: 226
# Trying to get data for rucheng
#
# Index: 227
# Trying to get data for ahipara
#
# Index: 228
# Trying to get data for kodiak
#
# Index: 229
# Trying to get data for bambous virieux
#
# Index: 230
# Trying to get data for hanzhong
#
# Index: 231
# Trying to get data for port lincoln
#
# Index: 232
# Trying to get data for dikson
#
# Index: 233
# Trying to get data for vestmannaeyjar
#
# Index: 234
# Trying to get data for ixtapa
#
# Index: 235
# Trying to get data for one hundred mile house
#
# one hundred mile house pull failed
#
# Index: 236
# Trying to get data for yanji
#
# Index: 237
# Trying to get data for puerto maldonado
#
# Index: 238
# Trying to get data for peruibe
#
# Index: 239
# Trying to get data for bonavista
#
# Index: 240
# Trying to get data for maragogi
#
# Index: 241
# Trying to get data for port elizabeth
#
# Index: 242
# Trying to get data for lere
#
# Index: 243
# Trying to get data for adrar
#
# Index: 244
# Trying to get data for balkanabat
#
# Index: 245
# Trying to get data for stamsund
#
# stamsund pull failed
#
# Index: 246
# Trying to get data for madang
#
# Index: 247
# Trying to get data for klaksvik
#
# Index: 248
# Trying to get data for elizabeth city
#
# Index: 249
# Trying to get data for ugoofaaru
#
# Index: 250
# Trying to get data for izumo
#
# Index: 251
# Trying to get data for basco
#
# Index: 252
# Trying to get data for tsihombe
#
# tsihombe pull failed
#
# Index: 253
# Trying to get data for tulsipur
#
# Index: 254
# Trying to get data for vaitape
#
# Index: 255
# Trying to get data for quba
#
# Index: 256
# Trying to get data for sola
#
# Index: 257
# Trying to get data for portree
#
# Index: 258
# Trying to get data for progreso
#
# Index: 259
# Trying to get data for don sak
#
# Index: 260
# Trying to get data for akcakoca
#
# Index: 261
# Trying to get data for luderitz
#
# Index: 262
# Trying to get data for iqaluit
#
# Index: 263
# Trying to get data for codrington
#
# Index: 264
# Trying to get data for taburi
#
# taburi pull failed
#
# Index: 265
# Trying to get data for banjar
#
# Index: 266
# Trying to get data for kipini
#
# Index: 267
# Trying to get data for san-pedro
#
# Index: 268
# Trying to get data for roebourne
#
# Index: 269
# Trying to get data for namibe
#
# Index: 270
# Trying to get data for nakhon phanom
#
# Index: 271
# Trying to get data for mehamn
#
# Index: 272
# Trying to get data for raton
#
# Index: 273
# Trying to get data for tasiilaq
#
# Index: 274
# Trying to get data for avarua
#
# Index: 275
# Trying to get data for balabac
#
# Index: 276
# Trying to get data for bilibino
#
# Index: 277
# Trying to get data for ornskoldsvik
#
# Index: 278
# Trying to get data for hay river
#
# Index: 279
# Trying to get data for touros
#
# Index: 280
# Trying to get data for pandan
#
# Index: 281
# Trying to get data for wagar
#
# Index: 282
# Trying to get data for susangerd
#
# Index: 283
# Trying to get data for oistins
#
# Index: 284
# Trying to get data for pontes e lacerda
#
# Index: 285
# Trying to get data for huarmey
#
# Index: 286
# Trying to get data for porto walter
#
# Index: 287
# Trying to get data for fairbanks
#
# Index: 288
# Trying to get data for muros
#
# Index: 289
# Trying to get data for olinda
#
# Index: 290
# Trying to get data for crab hill
#
# crab hill pull failed
#
# Index: 291
# Trying to get data for antalaha
#
# Index: 292
# Trying to get data for meulaboh
#
# Index: 293
# Trying to get data for aykhal
#
# Index: 294
# Trying to get data for grand gaube
#
# Index: 295
# Trying to get data for moron
#
# Index: 296
# Trying to get data for havre
#
# Index: 297
# Trying to get data for namatanai
#
# Index: 298
# Trying to get data for bungu
#
# Index: 299
# Trying to get data for skagastrond
#
# skagastrond pull failed
#
# Index: 300
# Trying to get data for laguna
#
# Index: 301
# Trying to get data for masunga
#
# Index: 302
# Trying to get data for monte alegre
#
# Index: 303
# Trying to get data for merauke
#
# Index: 304
# Trying to get data for paralimni
#
# Index: 305
# Trying to get data for talagang
#
# Index: 306
# Trying to get data for husavik
#
# Index: 307
# Trying to get data for yarmouth
#
# Index: 308
# Trying to get data for bilma
#
# Index: 309
# Trying to get data for foumban
#
# Index: 310
# Trying to get data for gamba
#
# Index: 311
# Trying to get data for eirunepe
#
# Index: 312
# Trying to get data for camacha
#
# Index: 313
# Trying to get data for greenfield
#
# Index: 314
# Trying to get data for launceston
#
# Index: 315
# Trying to get data for ancud
#
# Index: 316
# Trying to get data for alice springs
#
# Index: 317
# Trying to get data for ilulissat
#
# Index: 318
# Trying to get data for faanui
#
# Index: 319
# Trying to get data for kahului
#
# Index: 320
# Trying to get data for nikolskiy
#
# Index: 321
# Trying to get data for nantucket
#
# Index: 322
# Trying to get data for longyearbyen
#
# Index: 323
# Trying to get data for guozhen
#
# Index: 324
# Trying to get data for roanoke rapids
#
# Index: 325
# Trying to get data for tura
#
# Index: 326
# Trying to get data for gizo
#
# Index: 327
# Trying to get data for miramar
#
# Index: 328
# Trying to get data for angoche
#
# Index: 329
# Trying to get data for moskovskiy
#
# Index: 330
# Trying to get data for rocha
#
# Index: 331
# Trying to get data for alofi
#
# Index: 332
# Trying to get data for beloha
#
# Index: 333
# Trying to get data for bathsheba
#
# Index: 334
# Trying to get data for flin flon
#
# Index: 335
# Trying to get data for saveni
#
# Index: 336
# Trying to get data for vostok
#
# Index: 337
# Trying to get data for lensk
#
# Index: 338
# Trying to get data for mogadouro
#
# Index: 339
# Trying to get data for beringovskiy
#
# Index: 340
# Trying to get data for san patricio
#
# Index: 341
# Trying to get data for amderma
#
# amderma pull failed
#
# Index: 342
# Trying to get data for winnemucca
#
# Index: 343
# Trying to get data for ijaki
#
# ijaki pull failed
#
# Index: 344
# Trying to get data for louisbourg
#
# louisbourg pull failed
#
# Index: 345
# Trying to get data for attawapiskat
#
# attawapiskat pull failed
#
# Index: 346
# Trying to get data for garowe
#
# Index: 347
# Trying to get data for arlit
#
# Index: 348
# Trying to get data for khash
# Index: 349
# Trying to get data for grand river south east
#
# grand river south east pull failed
#
# Index: 350
# Trying to get data for sumbawa
#
# sumbawa pull failed
#
# Index: 351
# Trying to get data for tiarei
#
# Index: 352
# Trying to get data for ustye
#
# Index: 353
# Trying to get data for bereda
#
# Index: 354
# Trying to get data for isangel
#
# Index: 355
# Trying to get data for ada
#
# Index: 356
# Trying to get data for assela
#
# assela pull failed
#
# Index: 357
# Trying to get data for lavrentiya
#
# Index: 358
# Trying to get data for bijar
#
# Index: 359
# Trying to get data for kodinsk
#
# Index: 360
# Trying to get data for el alto
#
# Index: 361
# Trying to get data for pisco
#
# Index: 362
# Trying to get data for airai
#
# Index: 363
# Trying to get data for thai nguyen
#
# Index: 364
# Trying to get data for chokurdakh
#
# Index: 365
# Trying to get data for capoterra
#
# Index: 366
# Trying to get data for guangyuan
#
# Index: 367
# Trying to get data for calabozo
#
# Index: 368
# Trying to get data for khanino
#
# Index: 369
# Trying to get data for yeppoon
#
# Index: 370
# Trying to get data for tsabong
#
# Index: 371
# Trying to get data for ocotal
#
# Index: 372
# Trying to get data for labuhan
#
# Index: 373
# Trying to get data for orange
#
# Index: 374
# Trying to get data for inta
#
# Index: 375
# Trying to get data for knin
#
# Index: 376
# Trying to get data for hobyo
#
# Index: 377
# Trying to get data for brownsburg
#
# Index: 378
# Trying to get data for villa union
#
# Index: 379
# Trying to get data for lincoln
#
# Index: 380
# Trying to get data for finschhafen
#
# Index: 381
# Trying to get data for traralgon
#
# Index: 382
# Trying to get data for eureka
#
# Index: 383
# Trying to get data for zigos
#
# Index: 384
# Trying to get data for bhainsdehi
#
# Index: 385
# Trying to get data for kununurra
#
# Index: 386
# Trying to get data for cam ranh
#
# Index: 387
# Trying to get data for kharan
#
# Index: 388
# Trying to get data for adjumani
#
# Index: 389
# Trying to get data for larap
#
# Index: 390
# Trying to get data for half moon bay
#
# Index: 391
# Trying to get data for la ligua
#
# Index: 392
# Trying to get data for bom despacho
#
# Index: 393
# Trying to get data for dwarka
#
# Index: 394
# Trying to get data for marawi
#
# Index: 395
# Trying to get data for sucua
#
# Index: 396
# Trying to get data for mocuba
#
# Index: 397
# Trying to get data for muisne
#
# Index: 398
# Trying to get data for tori
#
# Index: 399
# Trying to get data for newport
#
# Index: 400
# Trying to get data for kawalu
#
# Index: 401
# Trying to get data for porto novo
#
# Index: 402
# Trying to get data for ozgon
#
# ozgon pull failed
#
# Index: 403
# Trying to get data for lebu
#
# Index: 404
# Trying to get data for okha
#
# Index: 405
# Trying to get data for canutama
#
# Index: 406
# Trying to get data for tessalit
#
# Index: 407
# Trying to get data for la ronge
#
# Index: 408
# Trying to get data for saint-esteve
#
# Index: 409
# Trying to get data for lingao
#
# Index: 410
# Trying to get data for clyde river
#
# Index: 411
# Trying to get data for itoman
#
# Index: 412
# Trying to get data for shuangcheng
#
# Index: 413
# Trying to get data for mbuji-mayi
#
# Index: 414
# Trying to get data for fort-shevchenko
#
# Index: 415
# Trying to get data for ulaangom
#
# Index: 416
# Trying to get data for tumannyy
#
# tumannyy pull failed
#
# Index: 417
# Trying to get data for khromtau
#
# Index: 418
# Trying to get data for canon city
#
# Index: 419
# Trying to get data for kipushi
#
# Index: 420
# Trying to get data for tshikapa
#
# Index: 421
# Trying to get data for owo
#
# Index: 422
# Trying to get data for tevaitoa
#
# Index: 423
# Trying to get data for khonuu
#
# khonuu pull failed
#
# Index: 424
# Trying to get data for pitimbu
#
# Index: 425
# Trying to get data for bonthe
#
# Index: 426
# Trying to get data for stephenville
#
# Index: 427
# Trying to get data for shush
#
# Index: 428
# Trying to get data for paraiba do sul
#
# Index: 429
# Trying to get data for haines junction
#
# Index: 430
# Trying to get data for longkou
#
# Index: 431
# Trying to get data for yei
#
# Index: 432
# Trying to get data for maravilha
#
# Index: 433
# Trying to get data for porto nacional
#
# Index: 434
# Trying to get data for kadirli
#
# Index: 435
# Trying to get data for bambanglipuro
#
# Index: 436
# Trying to get data for pindi gheb
#
# Index: 437
# Trying to get data for dicabisagan
#
# Index: 438
# Trying to get data for yulara
#
# Index: 439
# Trying to get data for okakarara
#
# Index: 440
# Trying to get data for mahajanga
#
# Index: 441
# Trying to get data for kieta
#
# Index: 442
# Trying to get data for kurkino
#
# Index: 443
# Trying to get data for tarudant
#
# tarudant pull failed
#
# Index: 444
# Trying to get data for whitehaven
#
# Index: 445
# Trying to get data for perth
#
# Index: 446
# Trying to get data for linxia
#
# Index: 447
# Trying to get data for manadhoo
#
# Index: 448
# Trying to get data for calvinia
#
# Index: 449
# Trying to get data for abu jubayhah
#
# abu jubayhah pull failed
#
# Index: 450
# Trying to get data for kenai
#
# Index: 451
# Trying to get data for moses lake
#
# Index: 452
# Trying to get data for formoso do araguaia
#
# formoso do araguaia pull failed
#
# Index: 453
# Trying to get data for banda aceh
#
# Index: 454
# Trying to get data for belaya gora
#
# Index: 455
# Trying to get data for at-bashi
#
# Index: 456
# Trying to get data for nauta
#
# Index: 457
# Trying to get data for fuerte olimpo
#
# Index: 458
# Trying to get data for san carlos de bariloche
#
# Index: 459
# Trying to get data for korla
#
# Index: 460
# Trying to get data for miri
#
# Index: 461
# Trying to get data for portland
#
# Index: 462
# Trying to get data for kavieng
#
# Index: 463
# Trying to get data for presidencia roque saenz pena
#
# Index: 464
# Trying to get data for phangnga
#
# Index: 465
# Trying to get data for algeciras
#
# Index: 466
# Trying to get data for locri
#
# Index: 467
# Trying to get data for vanimo
#
# Index: 468
# Trying to get data for truro
#
# Index: 469
# Trying to get data for tautira
#
# Index: 470
# Trying to get data for san benito
#
# Index: 471
# Trying to get data for tarakan
#
# Index: 472
# Trying to get data for tougue
#
# Index: 473
# Trying to get data for kawambwa
#
# Index: 474
# Trying to get data for tuatapere
#
# Index: 475
# Trying to get data for marcona
#
# marcona pull failed
#
# Index: 476
# Trying to get data for morondava
#
# Index: 477
# Trying to get data for hambantota
#
# Index: 478
# Trying to get data for west wendover
#
# Index: 479
# Trying to get data for barra
#
# Index: 480
# Trying to get data for shetpe
#
# Index: 481
# Trying to get data for black river
#
# Index: 482
# Trying to get data for cheremshan
#
# Index: 483
# Trying to get data for anadyr
#
# Index: 484
# Trying to get data for orlik
#
# Index: 485
# Trying to get data for omsukchan
#
# Index: 486
# Trying to get data for tucuman
#
# Index: 487
# Trying to get data for srbac
#
# Index: 488
# Trying to get data for spassk-ryazanskiy
#
# Index: 489
# Trying to get data for bonfim
#
# Index: 490
# Trying to get data for masterton
#
# Index: 491
# Trying to get data for port hedland
#
# Index: 492
# Trying to get data for pacific grove
#
# Index: 493
# Trying to get data for tabou
#
# Index: 494
# Trying to get data for tungor
#
# Index: 495
# Trying to get data for yaan
#
# Index: 496
# Trying to get data for arica
#
# Index: 497
# Trying to get data for susehri
#
# Index: 498
# Trying to get data for fengkou
#
# Index: 499
# Trying to get data for brawley
#
# Index: 500
# Trying to get data for winton
#
# Index: 501
# Trying to get data for dingle
#
# Index: 502
# Trying to get data for umzimvubu
#
# umzimvubu pull failed
#
# Index: 503
# Trying to get data for egvekinot
#
# Index: 504
# Trying to get data for aguimes
#
# Index: 505
# Trying to get data for verkhniy avzyan
#
# Index: 506
# Trying to get data for hastings
#
# Index: 507
# Trying to get data for bandrele
#
# Index: 508
# Trying to get data for raudeberg
#
# Index: 509
# Trying to get data for magadan
#
# Index: 510
# Trying to get data for red bluff
#
# Index: 511
# Trying to get data for cumaribo
#
# cumaribo pull failed
#
# Index: 512
# Trying to get data for storforshei
#
# Index: 513
# Trying to get data for vardo
#
# Index: 514
# Trying to get data for port macquarie
#
# Index: 515
# Trying to get data for vao
#
# Index: 516
# Trying to get data for kaseda
#
# Index: 517
# Trying to get data for villa sandino
#
# Index: 518
# Trying to get data for yubileynyy
#
# Index: 519
# Trying to get data for manta
#
# Index: 520
# Trying to get data for pantai remis
#
# Index: 521
# Trying to get data for warqla
#
# warqla pull failed
#
# Index: 522
# Trying to get data for puerto escondido
#
# Index: 523
# Trying to get data for tabarqah
#
# tabarqah pull failed
#
# Index: 524
# Trying to get data for sal rei
# Index: 525
# Trying to get data for college
#
# Index: 526
# Trying to get data for tigzirt
#
# Index: 527
# Trying to get data for bolshegrivskoye
#
# bolshegrivskoye pull failed
#
# Index: 528
# Trying to get data for norman wells
#
# Index: 529
# Trying to get data for laurinburg
#
# Index: 530
# Trying to get data for muhororo
#
# Index: 531
# Trying to get data for dire dawa
#
# Index: 532
# Trying to get data for kadaya
#
# Index: 533
# Trying to get data for aksu
#
# Index: 534
# Trying to get data for kawardha
#
# Index: 535
# Trying to get data for carpenedolo
#
# Index: 536
# Trying to get data for gushikawa
#
# Index: 537
# Trying to get data for koumac
#
# Index: 538
# Trying to get data for hofn
#
# Index: 539
# Trying to get data for benalla
#
# Index: 540
# Trying to get data for jiazi
#
# Index: 541
# Trying to get data for besancon
#
# Index: 542
# Trying to get data for kirundo
#
# Index: 543
# Trying to get data for samarai
#
# Index: 544
# Trying to get data for urdzhar
#
# urdzhar pull failed
#
# Index: 545
# Trying to get data for rabo de peixe
#
# Index: 546
# Trying to get data for maldonado
#
# Index: 547
# Trying to get data for constitucion
#
# Index: 548
# Trying to get data for cluses
#
# Index: 549
# Trying to get data for tuktoyaktuk
#
# Index: 550
# Trying to get data for maunabo
#
# Index: 551
# Trying to get data for maceio
#
# Index: 552
# Trying to get data for kovdor
#
# Index: 553
# Trying to get data for grindavik
#
# Index: 554
# Trying to get data for akdepe
#
# Index: 555
# Trying to get data for mayo
#
# Index: 556
# Trying to get data for narsaq
#
# Index: 557
# Trying to get data for ruatoria
#
# ruatoria pull failed
#
# Index: 558
# Trying to get data for valguarnera caropepe
#
# Index: 559
# Trying to get data for balarampur
#
# Index: 560
# Trying to get data for ninghai
#
# Index: 561
# Trying to get data for bull savanna
#
# Index: 562
# Trying to get data for palin
#
# Index: 563
# Trying to get data for omboue
#
# Index: 564
# Trying to get data for praya
#
# Index: 565
# Trying to get data for high prairie
#
# Index: 566
# Trying to get data for waingapu
#
# Index: 567
# Trying to get data for camocim
#
# Index: 568
# Trying to get data for fez
#
# Index: 569
# Trying to get data for show low
#
# Index: 570
# Trying to get data for north bend
#
# Index: 571
# Trying to get data for faya
#
# Index: 572
# Trying to get data for kholtoson
#
# Index: 573
# Trying to get data for dandong
#
# Index: 574
# Trying to get data for indian head
#
# Index: 575
# Trying to get data for kaeo
#
# Index: 576
# Trying to get data for moindou
#
# Index: 577
# Trying to get data for suntar
#
# Index: 578
# Trying to get data for hearst
#
# Index: 579
# Trying to get data for sao joao da barra
#
# Index: 580
# Trying to get data for vanavara
#
# Index: 581
# Trying to get data for hihifo
#
# hihifo pull failed
#
# Index: 582
# Trying to get data for riohacha
#
# Index: 583
# Trying to get data for klokkarvik
#
# klokkarvik pull failed
#
# Index: 584
# Trying to get data for sayyan
#
# Index: 585
# Trying to get data for bubaque
#
# Index: 586
# Trying to get data for qarayeri
#
# Index: 587
# Trying to get data for cutzamala
#
# cutzamala pull failed
#
# Index: 588
# Trying to get data for fernie
#
# Index: 589
# Trying to get data for dakar
#
# Index: 590
# Trying to get data for belyy yar
#
# Index: 591
# Trying to get data for pinega
#
# Index: 592
# Trying to get data for honiara
#
# Index: 593
# Trying to get data for mayumba
#
# Index: 594
# Trying to get data for yukhnov
#
# Index: 595
# Trying to get data for san policarpo
#
# Index: 596
# Trying to get data for mergui
#
# mergui pull failed
#
# Index: 597
# Trying to get data for general roca
#
# Index: 598
# Trying to get data for hoquiam
#
# Index: 599
# Trying to get data for nalut
#
# Index: 600
# Trying to get data for mankono
#
# Index: 601
# Trying to get data for nelson bay
#
# Index: 602
# Trying to get data for sabang
#
# Index: 603
# Trying to get data for guerrero negro
#
# Index: 604
# Trying to get data for tuy hoa
#
# Index: 605
# Trying to get data for san cristobal
#
# Index: 606
# Trying to get data for selikhino
#
# Index: 607
# Trying to get data for genhe
#
# Index: 608
# Trying to get data for phan thiet
#
# Index: 609
# Trying to get data for erzin
#
# Index: 610
# Trying to get data for el faiyum
#
# el faiyum pull failed
#
# Index: 611
# Trying to get data for vila do maio
#
# Index: 612
# Trying to get data for monticello
#
# Index: 613
# Trying to get data for voh
#
# Index: 614
# Trying to get data for halalo
#
# halalo pull failed
#
# Index: 615
# Trying to get data for coahuayana
#
# Index: 616
# Trying to get data for dargaville
#
# Index: 617
# Trying to get data for chagda
#
# chagda pull failed
#
# Index: 618
# Trying to get data for kolvereid
#
# Index: 619
# Trying to get data for sawakin
#
# Index: 620
# Trying to get data for saravena

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame({
    'City':cities2,
    'Temp (F)':temp,
    'Humidity':humid,
    'Cloudiness':cloud,
    'Wind Speed (MPH)':wind,
    'Latitude':lat,
    'Longitude':lon
})

city_df.to_csv(output_data_file)

city_df.head()
# Out:
#       City  Temp (F)  Humidity  Cloudiness  Wind Speed (MPH)  Latitude  \
# 0    Okato     65.17        72          67              4.00    -39.20
# 1  Rikitea     77.81        79          51             16.33    -23.12
# 2     Auki     85.93        64          20              3.06     -8.77
# 3   Hasaki     46.45        76          75              9.17     35.73
# 4  Ushuaia     44.60        93          90              9.17    -54.80
#
#    Longitude
# 0     173.88
# 1    -134.97
# 2     160.70
# 3     140.83
# 4     -68.30

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
clean_df = city_df.loc[city_df['Humidity'] <= 100]

# %%
print (clean_df['Humidity'].max())
# Out:
# 100

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude = list(clean_df['Latitude'])
temperature = list(clean_df['Temp (F)'])

latvtemp = plt.scatter(latitude,temperature)
latvtemp = plt.title("Latitude vs Temperature")
latvtemp = plt.xlabel("Latitude")
latvtemp = plt.ylabel("Temperature (F)")

#This graph is comparing the temperature to the latitude of the Earth. Seems like the temperature gets higher near 0, 
#lower away from 0

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
latitude = list(clean_df['Latitude'])
humidity = list(clean_df['Humidity'])

latvtemp = plt.scatter(latitude,humidity)
latvtemp = plt.title("Latitude vs Humidity")
latvtemp = plt.xlabel("Latitude")
latvtemp = plt.ylabel("Humidity")

#Here we compare Humidity to Latitude. There doesn't seem to be a correlation.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
latitude = list(clean_df['Latitude'])
cloudiness = list(clean_df['Cloudiness'])

latvtemp = plt.scatter(latitude,cloudiness)
latvtemp = plt.title("Latitude vs Cloudiness")
latvtemp = plt.xlabel("Latitude")
latvtemp = plt.ylabel("Cloudiness")

#Here is cloudiness vs latitude. Once again, doesn't seem like a correlation.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
latitude = list(clean_df['Latitude'])
windspeed = list(clean_df['Wind Speed (MPH)'])

latvtemp = plt.scatter(latitude,windspeed)
latvtemp = plt.title("Latitude vs Wind Speed (MPH)")
latvtemp = plt.xlabel("Latitude")
latvtemp = plt.ylabel("Wind Speed (MPH)")

#This would be wind speed vs latitude. No signs of correlation at first glance.

# %% [markdown]
# ## Linear Regression

# %%
north_df = clean_df.loc[clean_df['Latitude'] >= 0]
south_df = clean_df.loc[clean_df['Latitude'] < 0]

# %% [markdown]
# ####  North & South Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x1 = north_df['Latitude']
y1 = north_df['Temp (F)']

x2 = south_df['Latitude']
y2 = south_df['Temp (F)']


tempvlatnorth = plt.subplot(1, 2, 1)
tempvlatnorth = plt.scatter(x1, y1)
tempvlatnorth = plt.title('North Hemisphere')
tempvlatnorth = plt.xlabel('Latitude')
tempvlatnorth = plt.ylabel('Temp (F)')
tempvlatnorth = plt.tight_layout()

slope, intercept, rvalue1, pvalue, stderr = st.linregress(x1, y1)
regress_values = x1 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
tempvlatnorth = plt.plot(x1,regress_values,"r-")
tempvlatnorth = plt.annotate(line_eq,(2,-20),fontsize=9,color="red")


tempvlatsouth = plt.subplot(1, 2, 2)
tempvlatsouth = plt.scatter(x2, y2)
tempvlatsouth = plt.title('South Hemisphere')
tempvlatsouth = plt.xlabel('Latitude')
tempvlatsouth = plt.ylabel('Temp (F)')
tempvlatsouth = plt.tight_layout()

slope, intercept, rvalue2, pvalue, stderr = st.linregress(x2, y2)
regress_values = x2 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
tempvlatsouth = plt.plot(x2,regress_values,"r-")
tempvlatsouth = plt.annotate(line_eq,(-30,45),fontsize=9,color="red")

print (rvalue1,rvalue2)

# Looking at these two graphs with linear regression marked, it comfirms the earlier theory.
# There seems to be a strong cooling effect when going north (r value of .86) and a warmness when approaching 0 latitude.
# However, the south graph shows that when going away from 0 towards the south, the temp cools down again.
# Decent correlation, r value = .58
# Out:
# -0.8572668516200532 0.5788856831935405

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x1 = north_df['Latitude']
y1 = north_df['Humidity']

x2 = south_df['Latitude']
y2 = south_df['Humidity']


tempvlatnorth = plt.subplot(1, 2, 1)
tempvlatnorth = plt.scatter(x1, y1)
tempvlatnorth = plt.title('North Hemisphere')
tempvlatnorth = plt.xlabel('Latitude')
tempvlatnorth = plt.ylabel('Humidity')
tempvlatnorth = plt.tight_layout()

slope, intercept, rvalue1, pvalue, stderr = st.linregress(x1, y1)
regress_values = x1 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
tempvlatnorth = plt.plot(x1,regress_values,"r-")
tempvlatnorth = plt.annotate(line_eq,(2,-20),fontsize=9,color="red")


tempvlatsouth = plt.subplot(1, 2, 2)
tempvlatsouth = plt.scatter(x2, y2)
tempvlatsouth = plt.title('South Hemisphere')
tempvlatsouth = plt.xlabel('Latitude')
tempvlatsouth = plt.ylabel('Humidity')
tempvlatsouth = plt.tight_layout()

slope, intercept, rvalue2, pvalue, stderr = st.linregress(x2, y2)
regress_values = x2 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
tempvlatsouth = plt.plot(x2,regress_values,"r-")
tempvlatsouth = plt.annotate(line_eq,(-30,45),fontsize=9,color="red")

print (rvalue1,rvalue2)

# We're seeing some pretty weak correlations here, probably nothing too certain. 
# If this truly had a correlation, it would say the farther north you go, the more humid it is.
# Out:
# 0.28112370348704385 0.3701374285751291

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x1 = north_df['Latitude']
y1 = north_df['Cloudiness']

x2 = south_df['Latitude']
y2 = south_df['Cloudiness']


tempvlatnorth = plt.subplot(1, 2, 1)
tempvlatnorth = plt.scatter(x1, y1)
tempvlatnorth = plt.title('North Hemisphere')
tempvlatnorth = plt.xlabel('Latitude')
tempvlatnorth = plt.ylabel('Cloudiness')
tempvlatnorth = plt.tight_layout()

slope, intercept, rvalue1, pvalue, stderr = st.linregress(x1, y1)
regress_values = x1 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
tempvlatnorth = plt.plot(x1,regress_values,"r-")
tempvlatnorth = plt.annotate(line_eq,(2,-20),fontsize=9,color="red")


tempvlatsouth = plt.subplot(1, 2, 2)
tempvlatsouth = plt.scatter(x2, y2)
tempvlatsouth = plt.title('South Hemisphere')
tempvlatsouth = plt.xlabel('Latitude')
tempvlatsouth = plt.ylabel('Cloudiness')
tempvlatsouth = plt.tight_layout()

slope, intercept, rvalue2, pvalue, stderr = st.linregress(x2, y2)
regress_values = x2 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
tempvlatsouth = plt.plot(x2,regress_values,"r-")
tempvlatsouth = plt.annotate(line_eq,(-30,45),fontsize=9,color="red")

print (rvalue1,rvalue2)

# We're seeing some very weak correlations here. Nothing to draw from this.
# If there were a correlation, it would say the farther north you go, the cloudier it is.
# Out:
# 0.2057777195252082 0.23164888602318648

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x1 = north_df['Latitude']
y1 = north_df['Wind Speed (MPH)']

x2 = south_df['Latitude']
y2 = south_df['Wind Speed (MPH)']


tempvlatnorth = plt.subplot(1, 2, 1)
tempvlatnorth = plt.scatter(x1, y1)
tempvlatnorth = plt.title('North Hemisphere')
tempvlatnorth = plt.xlabel('Latitude')
tempvlatnorth = plt.ylabel('Wind Speed (MPH)')
tempvlatnorth = plt.tight_layout()

slope, intercept, rvalue1, pvalue, stderr = st.linregress(x1, y1)
regress_values = x1 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
tempvlatnorth = plt.plot(x1,regress_values,"r-")
tempvlatnorth = plt.annotate(line_eq,(2,-20),fontsize=9,color="red")


tempvlatsouth = plt.subplot(1, 2, 2)
tempvlatsouth = plt.scatter(x2, y2)
tempvlatsouth = plt.title('South Hemisphere')
tempvlatsouth = plt.xlabel('Latitude')
tempvlatsouth = plt.ylabel('Wind Speed (MPH)')
tempvlatsouth = plt.tight_layout()

slope, intercept, rvalue2, pvalue, stderr = st.linregress(x2, y2)
regress_values = x2 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
tempvlatsouth = plt.plot(x2,regress_values,"r-")
tempvlatsouth = plt.annotate(line_eq,(-30,45),fontsize=9,color="red")

print (rvalue1,rvalue2)

# We're seeing some exceptionally weak correlations here. Nothing to draw from this.
# If there were any correlation to draw from this, it says the further south you go, the windier it is.
# Out:
# 0.04542814190921296 -0.27690619775538894
